# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %%
filename = r'..\data\results\OPM_results\game_dataset.csv'
df = pd.read_csv(filename)
df.rename(columns={'mode': 'condition'}, inplace=True)

# %%
filename = r'..\data\results\OPM_results\game_metrics_per_n_game.csv'
df = pd.read_csv(filename)
df.loc[df.condition == 'im', 'condition'] = "IM"
df.loc[df.condition == 'qm', 'condition'] = "QM"

# %%
df
# Out:
#    total_score  game_duration  p_green_bands  aver_time  green_steps_min  \
# 0         1074           3.40          68.42       12.6            31.43
# 1         2324           7.18          92.86       28.9            15.57
# 2         1183           2.57          90.91       15.5            26.45
#
#    band_gain_min  n_stars  points_per_star  n_hh_average  n_overkill_average  \
# 0          14.29       10           107.40          0.30                 1.5
# 1          11.00       10           232.40          2.40                 1.2
# 2          18.71        6           197.17          0.83                 0.6
#
#   condition  n_game subject
# 0        IM       1   test1
# 1        QM       1   test1
# 2        QM       2   test1

# %%
filename = r'..\data\results\OPM_results\game_metrics_im_tests.csv'
df = pd.read_csv(filename)
df.loc[df.condition == 'im', 'condition'] = "IM"
df.loc[df.condition == 'qm', 'condition'] = "QM"

# %%
df
# Out:
#    total_score  game_duration  p_green_bands  aver_time  green_steps_min  \
# 0          907           4.38         100.00       20.6            22.72
# 1         1753           3.87          81.82       12.6            32.38
# 2         1356           4.42          75.00       16.3            22.45
#
#    band_gain_min  n_stars  points_per_star  n_hh_average  n_overkill_average  \
# 0          13.40        5            181.4           1.2                3.25
# 1          23.81       10            175.3           0.5                0.10
# 2          11.41       10            135.6           0.9                0.90
#
#   condition  n_game subject
# 0        QM       1   test2
# 1        QM       2   test2
# 2        QM       3   test2

# %%
filename = r'..\data\results\OPM_results\game_metrics_8ch.csv'
df = pd.read_csv(filename)
df.loc[df.condition == 'im', 'condition'] = "IM"
df.loc[df.condition == 'qm', 'condition'] = "QM"

# %%
df
# Out:
#    total_score  game_duration  p_green_bands  aver_time  green_steps_min  \
# 0         3716           6.58          83.33      12.05            37.34
#
#    band_gain_min  n_stars  points_per_star  n_hh_average  n_overkill_average  \
# 0          26.64       20            185.8           0.3                0.65
#
#   condition  n_game    subject
# 0        QM       1  test3_8ch

# %%
filename = r'..\data\results\OPM_results\game_metrics_eeg_opm_tests.csv'
df = pd.read_csv(filename)
df.loc[df.condition == 'im', 'condition'] = "IM"
df.loc[df.condition == 'qm', 'condition'] = "QM"

# %%
df
# Out:
#    total_score  game_duration  p_green_bands  aver_time  green_steps_min  \
# 0         3092           9.22          96.67      26.20            19.24
# 1          674           2.50          64.29      14.00            23.27
# 2         -590           1.03          16.67       9.75            10.77
# 3          630           2.68          94.44      39.33            12.20
# 4         4832           8.63          98.33      17.00            30.53
#
#    band_gain_min  n_stars  points_per_star  n_hh_average  n_overkill_average  \
# 0          13.89       15           206.13          1.27                2.07
# 1           6.12        7            96.29          0.57                0.83
# 2         -38.46        4          -147.50          0.00                1.00
# 3           9.15        3           210.00          1.00                1.33
# 4          26.47       20           241.60          0.90                0.80
#
#   condition  n_game        subject             filename
# 0       eeg       1  test4_eeg_opm   ['eeg_log_game_1']
# 1       eeg       2  test4_eeg_opm  ['eeg_log_game_80']
# 2       eeg       3  test4_eeg_opm  ['eeg_log_game_95']
# 3       opm       1  test4_eeg_opm   ['opm_log_game_1']
# 4       opm       2  test4_eeg_opm   ['opm_log_game_2']
